# %%
#importing all libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker
import matplotlib.ticker as plticker
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
#loading the ds files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import csv
df=pd.read_csv('/content/drive/MyDrive/Dataset/World Cup 2019 Dataset.csv')
df
# Out:
#            Team Group  Previous \r\nappearances  Previous \r\ntitles  \
# 0       England     A                        11                    0
# 1  South Africa     A                         6                    0
# 2   West Indies     A                        11                    2
# 3      Pakistan     A                        11                    1
# 4   New Zealand     A                        11                    0
# 5     Sri Lanka     A                        11                    1
# 6   Afghanistan     A                         1                    0
# 7     Australia     A                        11                    5
# 8    Bangladesh     A                         5                    0
# 9         India     A                        11                    2
#
#    Previous\r\n finals  Previous\r\n semifinals  Current \r rank
# 0                    3                        5                1
# 1                    0                        4                3
# ...

# %%
df=pd.read_csv('/content/drive/MyDrive/Dataset/results.csv')
df
# Out:
#           date        Team_1       Team_2        Winner     Margin  \
# 0     4-Jan-10    Bangladesh    Sri Lanka     Sri Lanka  7 wickets
# 1     5-Jan-10         India    Sri Lanka     Sri Lanka  5 wickets
# 2     7-Jan-10    Bangladesh        India         India  6 wickets
# 3     8-Jan-10    Bangladesh    Sri Lanka     Sri Lanka  9 wickets
# 4    10-Jan-10         India    Sri Lanka         India  8 wickets
# ..         ...           ...          ...           ...        ...
# 991  22-Oct-17         India  New Zealand   New Zealand  6 wickets
# 992  22-Oct-17  South Africa   Bangladesh  South Africa   200 runs
# 993  23-Oct-17      Pakistan    Sri Lanka      Pakistan  9 wickets
# 994  25-Oct-17         India  New Zealand         India  6 wickets
# 995  29-Oct-17         India  New Zealand         India     6 runs
#
#           Ground
# 0          Dhaka
# 1          Dhaka
# 2          Dhaka
# 3          Dhaka
# 4          Dhaka
# ..           ...
# 991       Mumbai
# ...

# %%
world_cup = pd.read_csv('/content/drive/MyDrive/Dataset/World Cup 2019 Dataset.csv')

# %%
results = pd.read_csv('/content/drive/MyDrive/Dataset/results.csv')

# %%
world_cup.head()
# Out:
#            Team Group  Previous \r\nappearances  Previous \r\ntitles  \
# 0       England     A                        11                    0
# 1  South Africa     A                         6                    0
# 2   West Indies     A                        11                    2
# 3      Pakistan     A                        11                    1
# 4   New Zealand     A                        11                    0
#
#    Previous\r\n finals  Previous\r\n semifinals  Current \r rank
# 0                    3                        5                1
# 1                    0                        4                3
# 2                    3                        4                8
# 3                    2                        6                6
# 4                    1                        7                4

# %%
results.head()
# Out:
#         date      Team_1     Team_2     Winner     Margin Ground
# 0   4-Jan-10  Bangladesh  Sri Lanka  Sri Lanka  7 wickets  Dhaka
# 1   5-Jan-10       India  Sri Lanka  Sri Lanka  5 wickets  Dhaka
# 2   7-Jan-10  Bangladesh      India      India  6 wickets  Dhaka
# 3   8-Jan-10  Bangladesh  Sri Lanka  Sri Lanka  9 wickets  Dhaka
# 4  10-Jan-10       India  Sri Lanka      India  8 wickets  Dhaka

# %%
#the above head command is to display the head of the ds files i.e the first 5 data

# %%
#filtering the matches played by india
df = results[(results['Team_1'] == 'India')|(results['Team_2'] == 'India')]
india = df.iloc[:]
india.head()
# Out:
#         date      Team_1     Team_2     Winner     Margin Ground
# 1   5-Jan-10       India  Sri Lanka  Sri Lanka  5 wickets  Dhaka
# 2   7-Jan-10  Bangladesh      India      India  6 wickets  Dhaka
# 4  10-Jan-10       India  Sri Lanka      India  8 wickets  Dhaka
# 5  11-Jan-10  Bangladesh      India      India  6 wickets  Dhaka
# 6  13-Jan-10       India  Sri Lanka  Sri Lanka  4 wickets  Dhaka

# %%
#creating a column for the matches played in 2010 for reference purpose
year = []
for row in india['date']:
  year.append(int(row[7:]))
india['match_year']=year
india_2010 = india[india.match_year >=10]
india_2010.count()
# Out:
# date          151
# Team_1        151
# Team_2        151
# Winner        151
# Margin        142
# Ground        151
# match_year    151
# dtype: int64

# %%
#merging all the teams together participatinng inn the WC
worldcup_teams = ['England','South Africa','West Indies','Pakistan','New Zealand','Sri Lanka','Afghanistan','Australia','Bangladesh','India']
df_teams_1 = results[results['Team_1'].isin(worldcup_teams)]
df_teams_2 = results[results['Team_2'].isin(worldcup_teams)]
df_teams = pd.concat((df_teams_1 ,df_teams_2))
df_teams.drop_duplicates()
df_teams.count()
# Out:
# date      1597
# Team_1    1597
# Team_2    1597
# Winner    1597
# Margin    1515
# Ground    1597
# dtype: int64

# %%
#display the results of the newly created dataframe
df_teams.head()
# Out:
#         date      Team_1     Team_2     Winner     Margin Ground
# 0   4-Jan-10  Bangladesh  Sri Lanka  Sri Lanka  7 wickets  Dhaka
# 1   5-Jan-10       India  Sri Lanka  Sri Lanka  5 wickets  Dhaka
# 2   7-Jan-10  Bangladesh      India      India  6 wickets  Dhaka
# 3   8-Jan-10  Bangladesh  Sri Lanka  Sri Lanka  9 wickets  Dhaka
# 4  10-Jan-10       India  Sri Lanka      India  8 wickets  Dhaka

# %%
df_teams_2010 = df_teams.drop(['date','Margin','Ground'], axis=1)
df_teams_2010.head()
# Out:
#        Team_1     Team_2     Winner
# 0  Bangladesh  Sri Lanka  Sri Lanka
# 1       India  Sri Lanka  Sri Lanka
# 2  Bangladesh      India      India
# 3  Bangladesh  Sri Lanka  Sri Lanka
# 4       India  Sri Lanka      India

# %%
#deleting the unwanted columns

# %%
#building the model
# the prediction label : the winning column will be shown 1 if team1 is won and 2 if team2 is won

df_teams_2010 = df_teams_2010.reset_index(drop=True)
df_teams_2010.loc[df_teams_2010.Winner == df_teams_2010.Team_1,'winning_team']=1
df_teams_2010.loc[df_teams_2010.Winner == df_teams_2010.Team_2,'winning_team']=2
df_teams_2010 = df_teams_2010.drop(['winning_team'], axis=1)

df_teams_2010.head()
# Out:
#        Team_1     Team_2     Winner
# 0  Bangladesh  Sri Lanka  Sri Lanka
# 1       India  Sri Lanka  Sri Lanka
# 2  Bangladesh      India      India
# 3  Bangladesh  Sri Lanka  Sri Lanka
# 4       India  Sri Lanka      India

# %%
# convert team 1 and team 2 from categorial variables to continous inputs

final =pd.get_dummies(df_teams_2010, prefix=['Team_1','Team_2'], columns=['Team_1','Team_2'])

#separate X and Y sets

X = final.drop(['Winner'], axis=1)
y = final["Winner"]

# dividing the data for training and testing
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size=0.30, random_state=42)

# %%
# display the first 5 data rows of final dataset

final.head()
# Out:
#       Winner  Team_1_Afghanistan  Team_1_Australia  Team_1_Bangladesh  \
# 0  Sri Lanka               False             False               True
# 1  Sri Lanka               False             False              False
# 2      India               False             False               True
# 3  Sri Lanka               False             False               True
# 4      India               False             False              False
#
#    Team_1_Canada  Team_1_England  Team_1_India  Team_1_Ireland  Team_1_Kenya  \
# 0          False           False         False           False         False
# 1          False           False          True           False         False
# 2          False           False         False           False         False
# 3          False           False         False           False         False
# 4          False           False          True           False         False
#
#    Team_1_Netherlands  ...  Team_2_Kenya  Team_2_Netherlands  \
# ...

# %%
logreg = LogisticRegression()
logreg.fit(X_train , y_train)
score = logreg.score(X_train , y_train)
score2 = logreg.score(X_test , y_test)

print("Testing set accuracy :",'%.3f'%(score))
print("Test set accuracy :",'%.3f'%(score2))
# Out:
# Testing set accuracy : 0.706
# Test set accuracy : 0.635

# %%
# adding ICC rankings
# teams with higher ranking will be considered as favourite for the match and will be positioned under team1 column
# loading the data sets

ranking = pd.read_csv('/content/drive/MyDrive/Dataset/icc_rankings.csv')
fixtures = pd.read_csv('/content/drive/MyDrive/Dataset/fixtures.csv')

# list for sorting the group stage games

pred_set = []

# %%
# create new columns with ranking position of teams

fixtures.insert(1,'first_position',fixtures['Team_1'].map( ranking.set_index('Team')['Position']))
fixtures.insert(2,'second_position',fixtures['Team_2'].map( ranking.set_index('Team')['Position']))

# we only need group stage matches

fixttures = fixtures.iloc[:45, :]
fixtures.tail()
# Out:
#    Round Number  first_position  second_position        Date  \
# 43            1             9.0              2.0    6/7/2019
# 44            1             5.0              3.0    6/7/2019
# 45  Semi Finals             NaN              NaN    9/7/2019
# 46  Semi Finals             NaN              NaN   11/7/2019
# 47       Finals             NaN              NaN  14/07/2019
#
#                              Location           Team_1           Team_2  \
# 43                  Headingley, Leeds        Sri Lanka            India
# 44  Emirates Old Trafford, Manchester        Australia     South Africa
# 45  Emirates Old Trafford, Manchester  To be announced  To be announced
# 46              Edgbaston, Birmingham  To be announced  To be announced
# 47                     Lord's, London  To be announced  To be announced
#
#      Group   Result
# 43  Group A     NaN
# 44  Group A     NaN
# 45      NaN     NaN
# 46      NaN     NaN
# 47      NaN     NaN

# %%
# adding loop for new predictions based on rankings

for index, row in fixtures.iterrows():
  if row['first_position'] < row['second_position']:
    pred_set.append({'Team_1': row['Team_1'], 'Team_2': row['Team_2'], 'winning_team': None })
  else :
    pred_set.append({'Team_1': row['Team_2'], 'Team_2' : row['Team_1'], 'winning_team': None })

pred_set = pd.DataFrame(pred_set)
backup_pred_set = pred_set
pred_set.head()
# Out:
#          Team_1        Team_2 winning_team
# 0       England  South Africa         None
# 1      Pakistan   West Indies         None
# 2   New Zealand     Sri Lanka         None
# 3     Australia   Afghanistan         None
# 4  South Africa    Bangladesh         None

# %%
# get dummy variables and drop winning_team column
pred_set = pd.get_dummies(pred_set , prefix = ['Team_1','Team_2'], columns =['Team_1','Team_2'])

# add missing columns compared to model data set

missing_cols = set(final.columns) - set(pred_set.columns)

for c in missing_cols :
  pred_set[c] = 0
pred_set = pred_set[final.columns]



pred_set = pred_set.drop(['Winner'], axis =1)
pred_set.head()
# Out:
#    Team_1_Afghanistan  Team_1_Australia  Team_1_Bangladesh  Team_1_Canada  \
# 0                   0             False              False              0
# 1                   0             False              False              0
# 2                   0             False              False              0
# 3                   0              True              False              0
# 4                   0             False              False              0
#
#    Team_1_England  Team_1_India  Team_1_Ireland  Team_1_Kenya  \
# 0            True         False               0             0
# 1           False         False               0             0
# 2           False         False               0             0
# 3           False         False               0             0
# 4           False         False               0             0
#
#    Team_1_Netherlands  Team_1_New Zealand  ...  Team_2_Kenya  \
# 0                   0               False  ...             0
# ...

# %%
# results of league stage matches

predictions = logreg.predict(pred_set)
for i in range(fixtures.shape[0]):
  print(backup_pred_set.iloc[i, 1] + "and" + backup_pred_set.iloc[i, 0])
  if predictions[i] == 1:
    print("Winner:" + backup_pred_set.iloc[i, 1])

  else :
    print("Winner : " + backup_pred_set.iloc[i, 0])
  print("")
# Out:
# South AfricaandEngland
# Winner : England
#
# West IndiesandPakistan
# Winner : Pakistan
#
# Sri LankaandNew Zealand
# Winner : New Zealand
#
# AfghanistanandAustralia
# Winner : Australia
#
# BangladeshandSouth Africa
# Winner : South Africa
#
# PakistanandEngland
# Winner : England
#
# AfghanistanandSri Lanka
# Winner : Sri Lanka
#
# South AfricaandIndia
# Winner : India
#
# BangladeshandNew Zealand
# Winner : New Zealand
#
# West IndiesandAustralia
# Winner : Australia
#
# Sri LankaandPakistan
# Winner : Pakistan
#
# BangladeshandEngland
# Winner : England
#
# AfghanistanandNew Zealand
# Winner : New Zealand
#
# AustraliaandIndia
# Winner : India
#
# West IndiesandSouth Africa
# Winner : South Africa
#
# Sri LankaandBangladesh
# Winner : Bangladesh
#
# PakistanandAustralia
# Winner : Australia
#
# New ZealandandIndia
# Winner : India
#
# West IndiesandEngland
# Winner : England
#
# Sri LankaandAustralia
# Winner : Australia
#
# AfghanistanandSouth Africa
# Winner : South Africa
#
# ...

# %%
#  list of our semi predicted

semi = [('India','Pakistan'),('New Zealand','South Africa')]

# %%
def clean_and_predict(matches, rankinng , final , logreg):

  #initializing the list for data cleaning

  positions = []
  # loop to retrive each teams position according to ICC

  for match in matches :
    positions.append(ranking.loc[ranking['Team'] == match[0], 'Position'].iloc[0])
    positions.append(ranking.loc[ranking['Team'] == match[1], 'Position'].iloc[0])


  # creating a data frame for prediction
  pred_set = []

  # initializing itteration for while loop
  i = 0
  j = 0

  # i is the position list and j is the list of matches fixtures

  while i < len(positions) :
    dict1 = {}

    # if the position of this team is better then this team then it will be considered as the team 1

    if positions[i] < positions[i + 1]:
      dict1.update({'Team_1': matches[j][0] , 'Team_2' : matches[j][1]})
    else :
      dict1.update({'Team_1': matches[j][1] , 'Team_2' : matches[i][0]})


    pred_set.append(dict1)
    i += 2
    j += 1


    #converting list into dataframe
    pred_set = pd.DataFrame (pred_set)
    backup_pred_set = pred_set


    # get dummy variables and drop winning_team column
    pred_set = pd.get_dummies(pred_set, prefix= ['Team_1' , 'Team_2'], columns=['Team_1', 'Team_2'])



    # adding missing columns compared to models training dataset
    missing_cols2 = set(final.columns) - set(pred_set.columns)
    for c in missing_cols2:
      pred_set[c] = 0
    pred_set = pred_set[final.columns]

    pred_set = pred_set.drop(['Winner'], axis=1)


    # predict

    predictions = logreg.predict(pred_set)

    for i in range(len(pred_set)):
      print(backup_pred_set.iloc[i, 1] + "and" + backup_pred_set.iloc[i, 0])
      if predictions[i] == 1:
           print("Winner:" + backup_pred_set.iloc[i, 1])

      else :
           print("Winner : " + backup_pred_set.iloc[i, 0])
      print("")

# %%
clean_and_predict(semi , ranking , final , logreg )
# Out:
# PakistanandIndia
# Winner : India
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-79ff4d1fd799> in <cell line: 1>()
# ----> 1 clean_and_predict(semi , ranking , final , logreg )
#
# <ipython-input-56-ede964ca35aa> in clean_and_predict(matches, rankinng, final, logreg)
#      31
#      32
# ---> 33     pred_set.append(dict1)
#      34     i += 2
#      35     j += 1
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
def clean_and_predict(matches, ranking, final, logreg):
    positions = []
    for match in matches:
        positions.append(ranking.loc[ranking['Team'] == match[0], 'Position'].iloc[0])
        positions.append(ranking.loc[ranking['Team'] == match[1], 'Position'].iloc[0])

    pred_set = []
    i = 0
    j = 0
    while i < len(positions):
        dict1 = {}
        if positions[i] < positions[i + 1]:
            dict1.update({'Team_1': matches[j][0], 'Team_2': matches[j][1]})
        else:
            dict1.update({'Team_1': matches[j][1], 'Team_2': matches[j][0]})
        pred_set.append(dict1)
        i += 2
        j += 1

    pred_set = pd.DataFrame(pred_set)
    backup_pred_set = pred_set

    pred_set = pd.get_dummies(pred_set, prefix=['Team_1', 'Team_2'], columns=['Team_1', 'Team_2'])

    missing_cols2 = set(final.columns) - set(pred_set.columns)
    for c in missing_cols2:
        pred_set[c] = 0
    pred_set = pred_set[final.columns]

    pred_set = pred_set.drop(['Winner'], axis=1, errors='ignore')  # Add errors='ignore' to avoid KeyError

    predictions = logreg.predict(pred_set)

    for i in range(len(pred_set)):
        print(backup_pred_set.iloc[i, 0] + " and " + backup_pred_set.iloc[i, 1])
        if predictions[i] == 1:
            print("Winner: " + backup_pred_set.iloc[i, 0])
        else:
            print("Winner: " + backup_pred_set.iloc[i, 1])
        print("")

# %%
clean_and_predict(semi , ranking , final , logreg )
# Out:
# India and Pakistan
# Winner: Pakistan
#
# South Africa and New Zealand
# Winner: New Zealand
